# %% [markdown]
# ## Import statements

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from itertools import product

# %% [markdown]
# ## Load captcha images

# %%
data = np.load('./preprocessed-data.npz')
X, y, y_labels = data['X'], data['y'], data['y_labels']

# %%
X.shape
# Out:
# (1070, 50, 200, 1)

# %% [markdown]
# ## Create our image generator

# %%
generator = ImageDataGenerator(
    width_shift_range=0.1,
    shear_range=0.15,
    rotation_range=7)

# %%
it = generator.flow(X[50:100, :, :, :], batch_size=32, shuffle=True)

# %% [markdown]
# ## Visualize our generated images

# %%
batch = next(it)

# %%
fig, ax = plt.subplots(8, 4, figsize=(14, 12))

for i, j in product(range(0, 8), range(0, 4)):
    plt.sca(ax[i, j])
    plt.imshow(batch[i * 4 + j, :, :, 0], cmap='gray')
    plt.xticks([])
    plt.yticks([])
    
plt.tight_layout()
